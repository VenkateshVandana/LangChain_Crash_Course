# %% [markdown]
# # LLM Call

# %%
import os
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model

load_dotenv()
groq_api_key = os.getenv("GROQ_API_KEY")

llm =init_chat_model(
    model="openai/gpt-oss-20b",
    model_provider="groq",
    temperature=0.5,
    api_key=groq_api_key
)

response = llm.invoke("What is the capital of France?")
response.content
# Out:
# 'The capital of France is **Paris**.'

# %% [markdown]
# # Messages

# %%
import os
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model
from langchain.messages import HumanMessage, SystemMessage, AIMessage

load_dotenv()
groq_api_key = os.getenv("GROQ_API_KEY")

llm =init_chat_model(
    model="openai/gpt-oss-20b",
    model_provider="groq",
    temperature=0.5,
    api_key=groq_api_key
)

messages = [
    HumanMessage(content="What is the capital of France?"),
    AIMessage(content="The capital of France is Paris."),
    SystemMessage(content="You are a helpful assistant that can answer questions about the world."),
    HumanMessage(content="Tell me about it?")
]

response = llm.invoke(messages)
print(response.content)
# Out:
# **Paris – The City of Light**
#
# | Category | Details |
# |----------|---------|
# | **Official name** | Paris |
# | **Country** | France |
# | **Region** | Île-de-France |
# | **Population** | ~2.1 million (city proper) – ~12 million in the metropolitan area |
# | **Area** | 105 km² (city) |
# | **Time zone** | Central European Time (CET/UTC+1), Central European Summer Time (CEST/UTC+2) |
# | **Postal codes** | 75001–75020 (districts) |
# | **Mayor (as of 2024)** | Anne Hidalgo (PS) |
# | **Website** | www.paris.fr |
#
# ---
#
# ### 1. Geography & Layout
# - **Location**: Center of France, on the Seine River.
# - **Arrondissements**: 20 administrative districts, numbered clockwise from the center.
# - **Key neighborhoods**: Marais, Latin Quarter, Montmartre, Saint‑Germain, Canal Saint‑Martin, Belleville, La Défense (business district).
#
# ### 2. History Highlights
# | Era | Key Events |
# |-----|------------|
# | **5th–6th c.** | Founded by the Parisii tribe; Gallo‑Roman city of Lutetia. |
# | **12th–14th c.** | Construction of Notre‑Dame, Sainte‑Clotilde, and the first university (Sorbonne). |
# | **16th c.** | Renaissance architecture (Palace of Versailles nearby). |
# | **18th c.** | French Revolution – Bastille falls (1789). |
# | **19th c.** | Haussmann’s renovation: wide boulevards, parks, sewer system. |
# | **20th c.** | World Wars, the rise of modern art, the 1968 protests. |
# | **21st c.** | Urban renewal, eco‑initiatives, Paris 2024 Olympic Games. |
#
# ### 3. Cultural & Artistic Significance
# - **Museums**: Louvre (world’s largest art museum), Musée d’Orsay (Impressionism), Centre Pompidou (modern art), Musée Rodin, Musée Picasso.
# - **Theater & Opera**: Palais Garnier, Opéra Bastille.
# - **Literature**: Café de Flore, Les Deux Magots – meeting places of existentialists.
# - **Fashion**: Paris Fashion Week (Spring/Summer & Fall/Winter).
# - **Cuisine**: Baguette, croissant, cheese, wine, Michelin‑starred restaurants (e.g., Le Meurice, L’Arpège).
#
# ### 4. Major Landmarks
# | Landmark | Description |
# |----------|-------------|
# | **Eiffel Tower** | 330 m iron lattice, built 1889; symbol of Paris. |
# | **Notre‑Dame de Paris** | Gothic cathedral (rebuilt after 2019 fire). |
# | **Arc de Triomphe** | Honors those who fought for France; at Place Charles‑de‑Gaulle. |
# | **Sacré‑Coeur** | Basilica on Montmartre hill, panoramic view. |
# | **Palace of Versailles** | Royal residence, famous gardens. |
# | **Luxembourg Gardens** | Formal gardens, Luxembourg Palace. |
# | **Seine River** | Cruises (Bateaux Mouches), Pont Neuf, Pont Alexandre III. |
#
# ### 5. Economy & Infrastructure
# - **GDP**: ~€300 billion (city).
# - **Key sectors**: Finance, luxury goods, tourism, technology, research.
# - **Transport**: Metro (16 lines, ~300 km), RER commuter rail, buses, trams, bike‑share (Vélib’), airports (Charles de Gaulle, Orly, Le Bourget).
# - **Education**: Sorbonne University, Sciences Po, École Normale Supérieure, HEC Paris, École Polytechnique (nearby).
#
# ### 6. Contemporary Issues
# - **Urban renewal**: La Défense expansion, eco‑districts (Paris Rive Gauche).
# - **Housing**: Rising rents, gentrification.
# - **Climate**: Paris Climate Agreement, “Paris Climate Action Plan” (target 40% renewable energy by 2030).
# - **COVID‑19**: Pandemic impacted tourism; recovery underway with new safety protocols.
#
# ### 7. Fun Facts
# - **“City of Light”**: Named for its early adoption of street lighting.
# - **Literary cafés**: Café de Flore served as a hub for Jean-Paul Sartre & Simone de Beauvoir.
# - **Fashion capital**: Hosts 12 major fashion weeks worldwide.
# - **Café culture**: 1,000 cafés per 100,000 residents.
# - **Public art**: 20,000 street art pieces in Montmartre and Belleville.
#
# ---
#
# **Quick Takeaway**
# Paris is a global epicenter of art, culture, politics, and cuisine. Its blend of ancient history and modern innovation makes it a living museum, a fashion runway, and a hub for international diplomacy. Whether you’re strolling along the Seine, exploring the Louvre, or sipping espresso in a sidewalk café, Paris offers an endlessly rich experience.

# %% [markdown]
# # Prompts

# %%
import os
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model
from langchain_core.prompts import PromptTemplate

load_dotenv()
groq_api_key = os.getenv("GROQ_API_KEY")


llm =init_chat_model(
    model="openai/gpt-oss-20b",
    model_provider="groq",
    temperature=0.5,
    api_key=groq_api_key
)

prompt=PromptTemplate.from_template("Tell me a joke about {subject}")

var=input("Enter a Subject for Joke: ")

chain = prompt | llm

response = chain.invoke({"subject": var})

print(response.content)
# Out:
# Why did the bat bring a baseball bat to the game?
# Because it heard the team needed a *bat* and it was ready to *hit* in the dark!

# %%
import os

from dotenv import load_dotenv
from langchain.chat_models import init_chat_model
from langchain_core.prompts import ChatPromptTemplate

# Load environment variables
load_dotenv()

groq_api_key = os.getenv("GROQ_API_KEY")

# Initialize the model
llm = init_chat_model(
    model="openai/gpt-oss-20b",
    model_provider="groq",
    temperature=0.5,
    api_key=groq_api_key
)

# Create prompt template
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a {expert}."),
    ("human", "{query}")
])

# Get user input
expert = input("Provide the context: ")
query = input("Enter a subject for the joke: ")

# Create chain
chain = prompt | llm

# Invoke chain
response = chain.invoke({
    "expert": expert,
    "query": query
})

# Print response
print(response.content)
# Out:
# Below is a **complete, self‑contained COBOL program** that copies the contents of one sequential file to another.
# It is written in ANSI‑COBOL (IBM Enterprise COBOL, Micro Focus, etc.) and will compile on any mainframe or z/OS environment that supports the standard file I/O model.
#
# > **What the program does**
# > 1. Opens an input file (`INPUT-FILE`).
# > 2. Opens an output file (`OUTPUT-FILE`).
# > 3. Reads each record from the input file and writes it unchanged to the output file.
# > 4. Handles end‑of‑file and basic file‑status errors.
# > 5. Closes both files and exits.
#
# ---
#
# ## 1. Source Code
#
# ```cobol
#        IDENTIFICATION DIVISION.
#        PROGRAM-ID. COPY-FILE.
#
#        ENVIRONMENT DIVISION.
#        INPUT-OUTPUT SECTION.
#        FILE-CONTROL.
#            SELECT INPUT-FILE
#                ASSIGN TO 'INPUT.DAT'
#                ORGANIZATION IS SEQUENTIAL
#                ACCESS MODE IS SEQUENTIAL
#                FILE STATUS IS IN-STATUS.
#
#            SELECT OUTPUT-FILE
#                ASSIGN TO 'OUTPUT.DAT'
#                ORGANIZATION IS SEQUENTIAL
#                ACCESS MODE IS SEQUENTIAL
#                FILE STATUS IS OUT-STATUS.
#
#        DATA DIVISION.
#        FILE SECTION.
#        FD  INPUT-FILE.
#        01  IN-RECORD        PIC X(80).   *> Adjust length to match your record size
#
#        FD  OUTPUT-FILE.
#        01  OUT-RECORD       PIC X(80).   *> Same length as IN-RECORD
#
#        WORKING-STORAGE SECTION.
#        01  IN-STATUS        PIC XX VALUE '00'.
#            88  IN-OK        VALUE '00'.
#            88  IN-EOF       VALUE '10'.
#            88  IN-ERROR     VALUE OTHER.
#
#        01  OUT-STATUS       PIC XX VALUE '00'.
#            88  OUT-OK       VALUE '00'.
#            88  OUT-ERROR    VALUE OTHER.
#
#        01  WS-ERROR-MSG     PIC X(80).
#
#        PROCEDURE DIVISION.
#        MAIN-LOGIC.
#            OPEN INPUT INPUT-FILE
#            IF NOT IN-OK
#                DISPLAY '*** ERROR: Cannot open INPUT-FILE. Status=' IN-STATUS
#                STOP RUN
#            END-IF
#
#            OPEN OUTPUT OUTPUT-FILE
#            IF NOT OUT-OK
#                DISPLAY '*** ERROR: Cannot open OUTPUT-FILE. Status=' OUT-STATUS
#                CLOSE INPUT-FILE
#                STOP RUN
#            END-IF
#
#            PERFORM UNTIL IN-EOF
#                READ INPUT-FILE
#                    AT END
#                        SET IN-EOF TO TRUE
#                    NOT AT END
#                        MOVE IN-RECORD TO OUT-RECORD
#                        WRITE OUT-RECORD
#                        IF NOT OUT-OK
#                            DISPLAY '*** ERROR: Write failed. Status=' OUT-STATUS
#                            CLOSE INPUT-FILE
#                            CLOSE OUTPUT-FILE
#                            STOP RUN
#                        END-IF
#                END-READ
#            END-PERFORM
#
#            CLOSE INPUT-FILE
#            CLOSE OUTPUT-FILE
#            DISPLAY '*** COPY COMPLETED SUCCESSFULLY.'
#            STOP RUN.
# ```
#
# ---
#
# ## 2. How to Build & Run
#
# | Step | Command (z/OS) | Notes |
# |------|----------------|-------|
# | 1 | `clgcl -c copy-file.cob` | Compile the program. |
# | 2 | `clgcl -x copy-file` | Link to create an executable. |
# | 3 | `//COPYFILE EXEC PGM=copy-file` | Run the program from a JCL step. |
#
# **JCL example**
#
# ```jcl
# //COPYJOB  JOB (ACCT),'COPY FILE',CLASS=A,MSGCLASS=A
# //STEP1    EXEC PGM=copy-file
# //INPUT    DD  DSN=your.input.dataset,DISP=SHR
# //OUTPUT   DD  DSN=your.output.dataset,DISP=(NEW,CATLG,DELETE),
# //            SPACE=(CYL,(1,1)),UNIT=SYSDA
# //SYSPRINT DD  SYSOUT=*
# //SYSOUT   DD  SYSOUT=*
# //SYSUDUMP DD  SYSOUT=*
# //SYSIN    DD  DUMMY
# ```
#
# Replace `your.input.dataset` and `your.output.dataset` with the actual dataset names.
# The program expects both files to be **sequential** and of the same record length (80 bytes in the example). Adjust `PIC X(80)` to match your real record size.
#
# ---
#
# ## 3. Things to Keep in Mind
#
# 1. **Record Length** – The `PIC X(n)` length must match the actual record size of the input file. If the input file is variable‑length, you’ll need a different record definition (e.g., `PIC X(200)` with a `REDEFINES` clause or `RECORDING MODE IS VARYING`).
#
# 2. **File Status Codes** –
#    * `00` = OK
#    * `10` = End‑of‑File (for input)
#    * Other codes indicate errors.
#    The program displays a simple error message and stops on any non‑OK status.
#
# 3. **Error Handling** – The example stops on the first error. In production you might want to log the error, attempt recovery, or write a bad‑record log.
#
# 4. **Performance** – For large files, consider using **buffered I/O** or **record‑level** copying (`REWRITE`/`MOVE` with `RECORDING MODE IS VARYING`) to reduce context switches.
#
# 5. **Environment** – This program uses the **SEQUENTIAL** organization. If you need to copy a **PL/I** or **VSAM** file, the file control section will differ.
#
# ---
#
# ## 4. Extending the Program
#
# | Feature | How to Add |
# |---------|------------|
# | **Progress Reporting** | Add a counter and display every 10,000 records. |
# | **Checksum** | Compute a CRC or simple sum of bytes and write it to a separate log. |
# | **Batch Parameters** | Use `PROCEDURE DIVISION USING` to pass input/output file names as parameters. |
# | **Error Log** | Write bad records to a separate dataset. |
# | **Parallel Copy** | Use multiple threads (in z/OS 2.3+ with COBOL) or split the file and run several instances. |
#
# ---
#
# ### Quick Test
#
# 1. Create a small test file:
#
# ```cobol
# //TESTIN   DD  DSN=TEST.INPUT,DISP=(NEW,CATLG,DELETE),
#           //        SPACE=(TRK,(1,1)),UNIT=SYSDA
# //SYSUT1   DD  UNIT=SYSDA,SPACE=(TRK,(1,1)),DCB=(RECFM=FB,LRECL=80)
# ```
#
# 2. Load some data into `TEST.INPUT` (e.g., using `IEBGENER` or a simple copy program).
# 3. Run the copy program as shown above.
# 4. Verify that `TEST.OUTPUT` contains the same data.
#
# ---
#
# **That’s it!**
# You now have a ready‑to‑compile COBOL copy program that can be dropped into any mainframe environment. Happy coding!
